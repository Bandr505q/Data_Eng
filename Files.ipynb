# %% [markdown]
# ## Exercise 1: Get Line Count in a File

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
with open("/home/bandr505/code/Projects/Data_Eng/read_demo.txt", 'r') as fp:
    for count, line in enumerate(fp):
        pass
print('Total Lines', count + 1)
# Out:
# Total Lines 8

# %% [markdown]
# ## Exercise 2: Search for a string in text file

# %% [markdown]
# I have a ‘sales.txt’ file that contains monthly sales data of items. I want the sales data of a specific item.

# %%
def search_str(file_path, word):
    with open(file_path, 'r') as file:
        # read all content of a file
        content = file.read()
        # check if string present in a file
        if word in content:
            print('string exist in a file')
        else:
            print('string does not exist in a file')

search_str('/home/bandr505/code/Projects/Data_Eng/sales.txt', 'laptop')
# Out:
# string exist in a file

# %% [markdown]
# ## Exercise 3: Check If File Exists

# %%
import os.path

# file to check
file_path = '/home/bandr505/code/Projects/Data_Eng/sales.txt'

flag = os.path.isfile(file_path)
if flag:
    print(f'The file {file_path} exists')
else:
    print(f'The file {file_path} does not exist')
    # you can create it if required
# Out:
# The file /home/bandr505/code/Projects/Data_Eng/sales.txt exists

# %% [markdown]
# ## Exercise 4: Check File Size

# %%
import os.path

# file to check
file_path = r'/home/bandr505/code/Projects/Data_Eng/sales.txt'

sz = os.path.getsize(file_path)
print(f'The {file_path} size is', sz, 'bytes')
# Out:
# The /home/bandr505/code/Projects/Data_Eng/sales.txt size is 51 bytes

# %% [markdown]
# ## Exercise 5: Write List to a File

# %% [markdown]
# ### Expected Outcome::
# ![image-removebg-preview (97).png](data:image/png;base64,...)

# %%
# list of names
names = ['Jessa', 'Eric', 'Bob']

# open file in write mode
with open('/home/bandr505/code/Projects/Data_Eng/newfile.txt', 'w') as fp:
    for item in names:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done
